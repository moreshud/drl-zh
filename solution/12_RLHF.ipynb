# %% [markdown]
# # Reinforcement Learning with Human Feedback
#
# [Large Language Models](https://en.wikipedia.org/wiki/Large_language_model) (LLMs) have been at the
# forefront of the present AI summer, making the generative AI field explode with innovation in recent
# years.
#
# LLMs are trained on vast amount of data in a self-supervised fashion (i.e., next token prediction),
# but they require lots of fine-tuning for them to be "user-friendly" and behave / respond in a way
# that humans consider appropriate (e.g., do not
# [hallucinate](<https://en.wikipedia.org/wiki/Hallucination_(artificial_intelligence)>)).
#
# Fine tuning LLMs generally happens in two stages:
#
# - **Supervised Fined-Tuning (SFT):** The pre-trained model is fine-tuned on a smaller, high-quality
#   dataset of labeled prompt-response pairs that demonstrate desired behaviors for specific tasks.
#   This helps the model become more useful and follow instructions.
# - **RLHF:** Human evaluators rank or provide preferences for different model outputs. The feedback
#   is used to train a "reward model," which guides the LLM to generate responses that are highly
#   preferred by humans (e.g., addressing safety, nuance, creativity, etc.) Here is a
#   [seminal paper](https://arxiv.org/abs/1909.08593) on the topic.
#
# ### RLHF Steps
#
# The starting point is to collect a "preference dataset", where human raters pick one LLM output
# preferred over another (or multiple ones). The preference dataset has tuples like:
#
# ```
# (prompt, output_1, output_2, human_preference)
# ```
#
# Then we use the preference dataset to train a _Reward Model_. The reward model is generally another
# LLM that takes a prompt and a completion, and outputs a _score_. Training the reward model is a hard
# task in and of itself, and in this notebook we will "fake" it using a hand-crafted reward function.
#
# At this point, we can introduce the reinforcement learning loop to fine-tune our original LLM! We
# need a second dataset containing many prompts (no completions!) which are analogous to "environment
# steps". Then, we feed the prompts to the model, which produces a completion, which is then scored
# via the reward model, and then weights are updated via PPO (or similar RL algorithm).
#
# ![RLHF diagram](../assets/12_RLHF_loop.excalidraw.png) <br><small>Reinforcement learning loop for
# LLM fine-tuning.</small>
#
# In this notebook, we will fine-tune a small language model to prefer telling stories about the
# animal kingdom!

# %%
# Import necessary classes from Hugging Face transformers library
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    AutoModelForSequenceClassification,
    PreTrainedModel,
)
from transformers import PreTrainedTokenizerBase

# Import necessary classes from PEFT (Parameter-Efficient Fine-Tuning) library for LoRA
from peft import get_peft_model, LoraConfig, TaskType

import torch
import torch.optim as optim
import torch.nn.functional as F

import random
import copy

from util.gymnastics import RLHF, DEVICE, init_random

# %% [markdown]
# We will use a [TinyStories](https://arxiv.org/abs/2305.07759) pretrained model that you can find on
# [HuggingFace](https://huggingface.co/roneneldan/TinyStories-33M). Moreover, we limit the output of
# the model to 60 tokens, to keep the generation relatively short and more efficient.

# %%
# Language model used in this notebook.
MODEL_NAME = "roneneldan/TinyStories-33M"

# Output length for training and sampling.
OUTPUT_LEN = 60

# Sample prompt for tests and consistent for comparison across epochs.
SAMPLE_PROMPT = "Once upon a time"

# %% [markdown]
# ## Models
#
# In order to be able to fine-tune a language-model, we need to understand the very basics of its
# architecture. In particular, at the foundation of modern LLMs is the _transformer architecture_,
# described in the popular paper ["Attention Is All You Need"](https://arxiv.org/abs/1706.03762).
#
# We will use the [Hugging Face transformers API](https://huggingface.co/docs/transformers/index).
# Reading the documentation before proceeding with the notebook is highly-recommended, because the
# notebook assumes familiarity with such APIs and concepts.
#
# First thing first, let's write a function to get a tokenizer for our model. A _tokenizer_ transforms
# text into the corresponding tensor tokens' numerical IDs.

# %%
def make_tokenizer(model_name=MODEL_NAME) -> PreTrainedTokenizerBase:
    # Load the tokenizer associated with the chosen model. The tokenizer converts text to numerical
    # IDs and back.
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    # Some models don't have a default padding token; set it to the end-of-sequence token in case.
    # This is important for batching (even if don't batch in this notebook) and consistent sequence
    # handling.
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    return tokenizer

# %% [markdown]
# We don't want to retrain the entire model for performance reasons. So we will use the HF
# [PEFT](https://huggingface.co/docs/transformers/en/peft) (Parameter Efficient Fine Tuning) library
# to create
# [LoRA adapters](https://huggingface.co/docs/peft/conceptual_guides/adapter#low-rank-adaptation-lora).
#
# Low-Rank Adaptation (LoRA) is one of the most popular PEFT methods, and allows to train a smaller
# subset of parameters added to the model's fixed parameters to tweak its behavior.
#
# Because we will use PPO for training, we will have both an actor and a critic model. Hence, we will
# create two LoRA configurations.

# %%
def make_lora_configs(r=16, alpha=32, dropout=0.05) -> tuple[LoraConfig, LoraConfig]:
    """LoRA (Low-Rank Adaptation) allows fine-tuning only a small number of parameters, saving
    memory and compute.

    Args:
        r (int): Rank of the LoRA decomposition matrices. Higher rank means more trainable
                 parameters (more capacity but slower).
        alpha (int): LoRA scaling factor, often set to 2*R. Balances the influence of LoRA
                     adapters vs base weights.
        dropout (float): Dropout probability within LoRA layers to prevent overfitting.
    """
    # Specify which layers / modules within the base model to apply LoRA adapters to.
    # Targeting attention projection layers (query, key, value) is common and effective.
    target_layers = ["q_proj", "k_proj", "v_proj"]

    # LoRA configuration specifically for the actor model (Causal Language Model task)
    actor_lora_config = LoraConfig(
        task_type=TaskType.CAUSAL_LM,
        r=r,
        lora_alpha=alpha,
        lora_dropout=dropout,
        target_modules=target_layers,
    )

    # LoRA configuration specifically for the critic model (Sequence Classification task)
    # Note: Use SEQ_CLS task type b/c we load the critic using AutoModelForSequenceClassification.
    # Also, we assume the base architecture shares "targetable" layer names with the CausalLM.
    critic_lora_config = LoraConfig(
        task_type=TaskType.SEQ_CLS,
        r=r,
        lora_alpha=alpha,
        lora_dropout=dropout,
        target_modules=target_layers,
    )
    return actor_lora_config, critic_lora_config

# %% [markdown]
# Finally, we can create the models used for training!

# %%
def make_training_models(
    tokenizer: PreTrainedTokenizerBase,
    model_name=MODEL_NAME,
) -> tuple[PreTrainedModel, PreTrainedModel, PreTrainedModel]:
    """Loads the pre-trained language models to use for RLHF fine-tuning.

    Returns:
        tuple: A tuple containing:
            - PreTrainedModel: the frozen reference model, used for KL-divergence computation and
                               reference during training.
            - PreTrainedModel: the "actor" model, i.e., the language model that is fine-tuned.
            - PreTrainedModel: the "critic" model, i.e., the model for classification used to
                               determine the "values" of the actor outputs.
    """
    # Load the base pre-trained language model for the Actor (policy network).
    base_actor_model = AutoModelForCausalLM.from_pretrained(model_name).to(DEVICE)

    # Load the base pre-trained model, but configure it for sequence classification to act as the
    # critic (value network). `num_labels=1` makes it output a single continuous value (regression),
    # suitable for predicting expected reward (value). This is a simplification; a more standard
    # critic might have a custom value head on the CausalLM base.
    base_critic_model = AutoModelForSequenceClassification.from_pretrained(
        model_name, num_labels=1
    ).to(DEVICE)

    # Ensure critic model knows the correct padding token ID, important for attention mechanisms.
    base_critic_model.config.pad_token_id = tokenizer.pad_token_id

    # Create a deep copy of the original *base* actor model as the reference model, before applying
    # LoRA. This model serves as a fixed reference point for the KL divergence calculation.
    ref_model = copy.deepcopy(base_actor_model).to(DEVICE)
    # Set the reference model to evaluation mode (disables dropout, etc.)
    ref_model.eval()
    # Freeze all parameters of the reference model, so they don't get updated during training.
    for param in ref_model.parameters():
        param.requires_grad = False

    # Wrap the base actor and critic models with LoRA adapters using the defined configurations.
    # `get_peft_model` modifies the model to insert LoRA layers and freezes the original weights.
    actor_lora_config, critic_lora_config = make_lora_configs()
    actor_model = get_peft_model(base_actor_model, actor_lora_config)
    critic_model = get_peft_model(base_critic_model, critic_lora_config)

    return ref_model, actor_model, critic_model

# %% [markdown]
# Let's now put some pieces together and create a function that invokes a model and generates a
# completion to an input prompt.

# %%
@torch.no_grad()
def generate(
    tokenizer: PreTrainedTokenizerBase,
    llm_model: PreTrainedModel,
    prompt: str,
    max_length: int = OUTPUT_LEN,
) -> tuple["transformers.BatchEncoding", torch.Tensor, str]:
    """Generates an output from the LLM model.

    Returns:
        tuple: A tuple containing:
            - BatchEncoding: the tokenized prompt (input_ids + attention_mask), on DEVICE.
            - Tensor: the response token IDs (shape `[1, response_len]`), excluding the prompt.
            - str: The decoded response text.
    """
    # Tokenize the current prompt text into numerical IDs for the model, truncating long prompts to
    # avoid exceeding our specified max_length.
    tokenized_prompt = tokenizer(
        prompt, return_tensors="pt", truncation=True, max_length=max_length // 2
    ).to(DEVICE)
    # Get token IDs and attention mask (which indicates which tokens are real vs padding).
    input_ids = tokenized_prompt.input_ids
    attention_mask = tokenized_prompt.attention_mask
    prompt_len = input_ids.shape[1]  # Store the length of the prompt section

    # Generate a response using the actor model (with LoRA). Use torch.no_grad() to avoid any
    # gradients calculation on generation (saving memory during inference).
    with torch.no_grad():
        outputs = llm_model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=max_length,  # Maximum length of prompt + response
            do_sample=True,  # Enable sampling (essential for exploration in PPO)
            pad_token_id=tokenizer.pad_token_id,  # Specify padding token ID
            eos_token_id=tokenizer.eos_token_id,  # Specify end-of-sequence token ID
            top_k=50,  # Sampling: consider only top 50 probable tokens
            top_p=0.95,  # Sampling: consider tokens summing up to 95% prob (nucleus sampling)
            # Sampling temperature: controls randomness (lower=more focused, higher=more random)
            temperature=0.7,
        )
    # Extract only the generated token IDs (excluding the prompt).
    response_ids = outputs[0][prompt_len:]
    # Decode the response token IDs back into human-readable text.
    response_text = tokenizer.decode(response_ids, skip_special_tokens=True)
    # Return response_ids with first being the batch (of size 1 in this simple notebook).
    return tokenized_prompt, response_ids.unsqueeze(0), response_text

# %% [markdown]
# Let's create the tokenizer and generate an example.

# %%
tokenizer = make_tokenizer()
ref_model, actor_model, critic_model = make_training_models(tokenizer)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# [transformers] GPTNeoForCausalLM LOAD REPORT from: roneneldan/TinyStories-33M
# Key                                                   | Status     |  |
# ------------------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3}.attn.attention.bias        | UNEXPECTED |  |
# transformer.h.{0, 1, 2, 3}.attn.attention.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# [transformers] GPTNeoForSequenceClassification LOAD REPORT from: roneneldan/TinyStories-33M
# Key                                                   | Status     |
# ------------------------------------------------------+------------+-
# transformer.h.{0, 1, 2, 3}.attn.attention.bias        | UNEXPECTED |
# transformer.h.{0, 1, 2, 3}.attn.attention.masked_bias | UNEXPECTED |
# score.weight                                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
_, _, output_text = generate(tokenizer, ref_model, prompt=SAMPLE_PROMPT)
print(f"{SAMPLE_PROMPT}{output_text}")
# Out:
# Once upon a time, there was a little girl named Lily. She loved to play outside in her backyard. One day, she found a big pit in the ground. It was very deep and she couldn't see the bottom.
#
# Lily's mom came outside and saw the pit too

# %% [markdown]
# ## Reward Model
#
# As previously mentioned, we are going to use an hard-coded function as our "pretend reward model"
# for simplicity and to avoid to train a full-fledged reward model. While this works in our limited
# educational RLHF example, it is certainly not effective for proper fine-tuning and alignment:
# [reward hacking](https://en.wikipedia.org/wiki/Reward_hacking) being one of the typical reasons.
#
# But for now, let's write a reward function that encourages telling stories about animals!

# %%
def animals_stories_reward(response: str) -> torch.Tensor:
    """Defines the reward signal used to guide the RL training.

    This simple function rewards mentioning animal words and penalizes mentioning human words.
    Note: Simple keyword-based rewards are easy for education but prone to "reward hacking".
    """
    # Preprocess the generated response. Strip surrounding punctuation so tokens like "cat," and
    # "dog." still match RLHF.ANIMAL_WORDS — a plain `.split()` would leave the punctuation
    # attached and silently miss those mentions.
    raw_words = response.lower().split()
    text_words = [w.strip(".,!?:;\"'()[]{}") for w in raw_words]
    response_length = len(text_words)

    # Count occurrences of animal and human words.
    animal_mentions = [word for word in text_words if word in RLHF.ANIMAL_WORDS]
    animal_score = len(animal_mentions)
    human_score = sum(1 for word in text_words if word in RLHF.HUMAN_WORDS)

    # Penalize very short responses.
    length_penalty = 0 if response_length > 4 else -1.0

    # Penalize excessive repetition of animal words.
    animal_threshold = max(5, int(0.15 * response_length))
    excessive_animal_penalty = 0
    if animal_score > animal_threshold:
        excessive_animal_penalty = -0.5 * (animal_score - animal_threshold)

    # Encourage a diversity of animal words.
    unique_animal_bonus = 0
    if animal_score > 0:
        unique_animal_bonus = 0.5 * len(set(animal_mentions))

    # Calculate final reward.
    reward = (
        (1.2 * animal_score)
        - (0.8 * human_score)
        + length_penalty
        + excessive_animal_penalty
        + unique_animal_bonus
    )
    return torch.tensor(reward, dtype=torch.float32, device=DEVICE)

# %%
def test_animals_stories_reward():
    # `animals_stories_reward` returns a tensor on DEVICE (which may be CUDA), while the expected
    # values below are built as plain CPU tensors. Compare on CPU so this test is device-robust.
    def _close(actual, expected):
        return torch.isclose(actual.cpu(), torch.tensor(expected))

    response1 = "The quick brown fox and a lion met a boy"
    expected_reward1 = 2.6
    actual_reward1 = animals_stories_reward(response1)
    assert _close(
        actual_reward1, expected_reward1
    ), f"FAILED Case 1: Expected {expected_reward1}, but got {actual_reward1.item()}"
    print("✅ Test Case 1 (Standard) Passed!")

    response2 = "a cat and dog"
    expected_reward2 = 2.4
    actual_reward2 = animals_stories_reward(response2)
    assert _close(
        actual_reward2, expected_reward2
    ), f"FAILED Case 2: Expected {expected_reward2}, but got {actual_reward2.item()}"
    print("✅ Test Case 2 (Short Response) Passed!")

    response3 = "cat dog lion tiger bear fox cat dog lion tiger bear fox"  # 12 words
    expected_reward3 = 13.9
    actual_reward3 = animals_stories_reward(response3)
    assert _close(
        actual_reward3, expected_reward3
    ), f"FAILED Case 3: Expected {expected_reward3}, but got {actual_reward3.item()}"
    print("✅ Test Case 3 (Excessive Animals) Passed!")

    response4 = "This is a simple sentence about nothing special"
    expected_reward4 = 0.0
    actual_reward4 = animals_stories_reward(response4)
    assert _close(
        actual_reward4, expected_reward4
    ), f"FAILED Case 4: Expected {expected_reward4}, but got {actual_reward4.item()}"
    print("✅ Test Case 4 (No Keywords) Passed!")

    # Punctuation guard: "cat," and "dog." must still match ANIMAL_WORDS even though
    # `str.split()` leaves the punctuation attached. Same scoring as response2.
    response5 = "a cat, and dog."
    actual_reward5 = animals_stories_reward(response5)
    assert _close(
        actual_reward5, expected_reward2
    ), f"FAILED Case 5 (Punctuation): Expected {expected_reward2}, but got {actual_reward5.item()}"
    print("✅ Test Case 5 (Punctuation) Passed!")


test_animals_stories_reward()
# Out:
# ✅ Test Case 1 (Standard) Passed!
# ✅ Test Case 2 (Short Response) Passed!
# ✅ Test Case 3 (Excessive Animals) Passed!
# ✅ Test Case 4 (No Keywords) Passed!
# ✅ Test Case 5 (Punctuation) Passed!

# %% [markdown]
# ## RLHF Fine Tuning w/ PPO
#
# Let's start by writing a helper function that computes the actual probabilities of the model output,
# with respect to the actual response. We will use this repeatedly in the training loop.

# %%
def actual_log_probs(
    logits_all: torch.Tensor, response_ids: torch.Tensor, prompt_len: int
) -> torch.Tensor:
    """Compute the log probabilities of the model output logits w.r.t. the *actual* response.

    Args:
        logits_all (torch.Tensor): The model output logits of prompt + response. The shape should
                                   be [batch, tokens, logits], where batch is always 1 in this
                                   notebook, tokens are prompt+response tokens, logits ~50k (i.e.,
                                   total number of tokens).
        response_ids (torch.Tensor): The actual response token IDs. Shape should be:
                                     [batch, response_tokens], in this notebook [1, 100].
        prompt_len (int): How long is the prompt.
    """
    log_probs_all = F.log_softmax(logits_all, dim=-1)
    # Define the start and end indices corresponding to the *generated response* tokens within the
    # full sequence logits. We need logits from position `prompt_len - 1` to predict tokens at
    # position `prompt_len`, up to the end.
    gen_start = prompt_len - 1
    # Index of the second-to-last token (predicting the last token).
    gen_end = logits_all.shape[1] - 1
    response_log_probs = log_probs_all[:, gen_start:gen_end, :]
    # The generated `response_ids` tensor needs correct shape for `gather`.
    # Shape: (1, gen_len) -> (1, gen_len, 1)
    gather_index = response_ids.unsqueeze(-1)
    # Use `gather` to select the log probabilities corresponding to the actual tokens generated by
    # the actor (remove last dim).
    # (1, 100, 50k) gathered by (1, 100, 1) -> selects (i, j, index[i, j, 1]), i.e., the actual
    # token logprob for each token.
    actual_log_probs = torch.gather(response_log_probs, 2, gather_index).squeeze(-1)
    return actual_log_probs

# %% [markdown]
# Here is an AI-generated unit-test :)

# %%
def test_actual_log_probs():
    batch_size = 1
    prompt_len = 3
    response_len = 2
    total_len = prompt_len + response_len

    logits_all = torch.tensor(
        [
            [  # Batch 0
                [0, 0, 0, 0, 0],  # Logits for token 1 (in prompt)
                [0, 0, 0, 0, 0],  # Logits for token 2 (in prompt)
                [1, 2, 3, 4, 5],  # Logits used to predict the 1st response token
                [5, 4, 3, 2, 1],  # Logits used to predict the 2nd response token
                [0, 0, 0, 0, 0],  # Logits for token after response (will be ignored)
            ]
        ],
        dtype=torch.float32,
    )

    response_ids = torch.tensor([[2, 0]], dtype=torch.int64)
    logits_for_response = logits_all[:, prompt_len - 1 : total_len - 1, :]
    expected_log_probs_slice = F.log_softmax(logits_for_response, dim=-1)
    log_prob_token1 = expected_log_probs_slice[0, 0, 2]
    log_prob_token2 = expected_log_probs_slice[0, 1, 0]

    expected_output = torch.tensor([[log_prob_token1, log_prob_token2]])

    actual_output = actual_log_probs(
        logits_all=logits_all,
        response_ids=response_ids,
        prompt_len=prompt_len,
    )

    assert actual_output.shape == (
        batch_size,
        response_len,
    ), f"FAILED: Expected shape {(batch_size, response_len)}, but got {actual_output.shape}"

    assert torch.allclose(
        actual_output, expected_output
    ), f"FAILED: Expected values {expected_output}, but got {actual_output}"

    print("✅ Test passed!")


test_actual_log_probs()
# Out:
# ✅ Test passed!

# %% [markdown]
# And finally... let's write our RLHF training loop using PPO! You should already by familiar with
# PPO's general training structure and loss function - feel free to take a peek at the PPO notebook
# solution to refresh your memory!
#
# One important detail about training is that the reward (that comes from the reward model) is
# counter-balanced by preventing the new model distribution to steer away too much from the original
# model distribution. Intuitively, we still want our language model to produce text in a similar way
# it currently does (and not finding ways to maximize reward that would instead produce unintelligible
# text).
#
# In order to do that, we measure the difference between the "reference" model distribution and the
# model under training via
# [KL divergence](https://en.wikipedia.org/wiki/Kullback%E2%80%93Leibler_divergence).
#
# $$
# D_{\text{KL}}(P \| Q) = \sum_i P(i) \log \frac{P(i)}{Q(i)}
# $$
#
# Which can be [efficiently approximated](http://joschu.net/blog/kl-approx.html) as:
#
# $$
# D_{\text{KL}}(P \| Q) = E_{X \sim P}\left[ \log P(X) - \log Q(X) \right]
# $$
#
# Understanding the mathematics behind these formulas would definitely be beneficial, but it is not
# necessary to still appreciate the overall RLHF training loop.

# %%
def rlhf_fine_tuning(
    actor_model: PreTrainedModel,
    critic_model: PreTrainedModel,
    num_epochs=50,
    n_epoch_updates=2,
    max_length=OUTPUT_LEN,
    actor_lr=5e-5,
    critic_lr=1e-4,
    kl_beta=0.1,
    epsilon=0.2,
    grad_clip_norm=1.0,
    seed=42,
):
    """Fine-tune an LLM using Reinforcement Learning w/ Human Feedback.

    Args:
        num_epochs (int): Number of times the training loop iterates over all prompts.
        max_length (int): Maximum sequence length for generated responses (including prompt).
                          Limits computational cost and output length.
        actor_lr (float): Learning rate for the actor (policy) model optimizer.
        critic_lr (float): Learning rate for the critic (value) model optimizer.
        kl_beta (float): Strength of the KL divergence penalty.
        epsilon (float): PPO clipping parameter; limits how much the policy changes in one update.
        grad_clip_norm (float): Maximum gradients norm to avoid exploding gradients.
        seed (int): Seed for deterministic training.
    """
    init_random(seed=seed)

    # Optimizers on the trainable parameters, i.e., LoRA weights.
    actor_optimizer = optim.Adam(actor_model.parameters(), lr=actor_lr)
    critic_optimizer = optim.Adam(critic_model.parameters(), lr=critic_lr)

    for epoch in range(num_epochs):
        # Dictionary of metrics to track during training.
        metrics = {
            "raw_scores": [],
            "rewards": [],
            "kl_divs": [],
            "ppo_losses": [],
            "critic_losses": [],
        }

        # Set models to training mode (enables dropout, LoRA updates, etc.)
        actor_model.train()
        critic_model.train()

        # Shuffle prompts randomly each epoch for better generalization.
        epoch_prompts = RLHF.PROMPTS.copy()
        random.shuffle(epoch_prompts)

        for prompt in epoch_prompts:
            # Generate Response (no grad).
            tokenized_prompt, response_ids, response_text = generate(
                tokenizer, actor_model, prompt, max_length
            )
            # Store the length of the response section.
            response_len = response_ids.shape[1]
            # Store the length of the prompt section.
            prompt_len = tokenized_prompt.input_ids.shape[1]

            # Concatenate prompt and response IDs to form the full sequence for model input.
            full_ids = torch.cat([tokenized_prompt.input_ids, response_ids], dim=1)
            # Create the corresponding attention mask for the full sequence (prompt mask + ones for
            # response b/c response has no padding).
            full_attention_mask = torch.cat(
                [
                    tokenized_prompt.attention_mask,
                    torch.ones(1, response_len, device=DEVICE, dtype=torch.long),
                ],
                dim=1,
            )

            # Calculate Metrics (Reward, KL, Value). Perform these calculations without tracking
            # gradients as they are inputs to the loss functions.
            with torch.no_grad():
                # Get logits (raw model outputs before activation) from the actor (PEFT model).
                # The actor model output has two fields: `logits` and `past_key_values` (for caching
                # attention computations).
                actor_logits = actor_model(full_ids, attention_mask=full_attention_mask).logits
                # Calculate the log probabilities using the response_ids.
                actor_log_probs = actual_log_probs(actor_logits, response_ids, prompt_len)

                # Get logits from the frozen reference model (original base model).
                ref_logits = ref_model(full_ids, attention_mask=full_attention_mask).logits
                # Calculate the log probabilities using the response_ids.
                ref_log_probs = actual_log_probs(ref_logits, response_ids, prompt_len)

                # Calculate the log probability of the generated sequence under the old policy
                # (current actor state). Sum the log probabilities across the sequence dimension
                # (dim=1). Squeeze to get a scalar tensor.
                log_probs_old = actor_log_probs.sum(dim=1).squeeze()

                # Get the value prediction from the critic (PEFT model) using the full sequence.
                critic_outputs = critic_model(full_ids, attention_mask=full_attention_mask)
                # The critic outputs logits; squeeze to get the scalar value prediction V(s).
                critic_value = critic_outputs.logits.squeeze()

                # Calculate the KL divergence between the actor and reference model distributions
                # for the generated sequence. KL(P || Q) approx E[log P - log Q] (sample)
                # Sum difference over sequence, get scalar.
                kl_div = (actor_log_probs - ref_log_probs).sum(dim=1).squeeze()

                # Get the base reward based on the generated text using the custom reward function.
                base_reward = animals_stories_reward(response_text)
                # Calculate the final reward used for PPO update: base reward minus the KL penalty.
                total_reward = base_reward - kl_beta * kl_div

            # Calculate the advantage A(s,a) = R - V(s) using the final reward and the value
            # estimate (scalar). Detach it (to be used as a constant target below).
            advantage = (total_reward - critic_value).detach()

            for _ in range(n_epoch_updates):
                # Perform a forward pass through the current actor model again with gradients
                # enabled to get the log probabilities of the generated sequence under the
                # current policy state.
                actor_logits_new = actor_model(full_ids, attention_mask=full_attention_mask).logits
                actor_log_probs_new = actual_log_probs(actor_logits_new, response_ids, prompt_len)
                log_probs_new = actor_log_probs_new.sum(dim=1).squeeze()

                # Calculate the probability ratio: ratio = exp(log_prob_new - log_prob_old).
                # Use the detached log_probs_old as it represents the fixed policy for this step.
                ratio = torch.exp(log_probs_new - log_probs_old.detach())

                # Clip the ratio to the range [1 - epsilon, 1 + epsilon].
                clipped_ratio = torch.clamp(ratio, 1 - epsilon, 1 + epsilon)

                # The PPO loss is the negative of the surrogate objective: the minimum between
                # ratio * advantage and clipped_ratio * advantage.
                ppo_loss = -torch.min(ratio * advantage, clipped_ratio * advantage)

                # Update Actor (Policy Network)
                actor_optimizer.zero_grad()
                ppo_loss.backward()
                torch.nn.utils.clip_grad_norm_(actor_model.parameters(), max_norm=grad_clip_norm)
                actor_optimizer.step()

                # Update Critic (Value Network)
                # Calculate the target value for the critic. Return = Advantage + V(s), which should
                # approximate the total_reward.
                returns = advantage + critic_value.detach()

                # Perform a forward pass through the current critic with gradients enabled to get
                # value prediction for the current state.
                critic_outputs_for_loss = critic_model(full_ids, attention_mask=full_attention_mask)
                critic_value_for_loss = critic_outputs_for_loss.logits.squeeze()  # Scalar tensor

                # Calculate the critic loss, MSE between predicted value and target return.
                critic_loss = F.mse_loss(critic_value_for_loss, returns)

                critic_optimizer.zero_grad()
                critic_loss.backward()
                torch.nn.utils.clip_grad_norm_(critic_model.parameters(), max_norm=grad_clip_norm)
                critic_optimizer.step()

            # Store metrics for this step.
            metrics["raw_scores"].append(base_reward)
            metrics["rewards"].append(total_reward.item())
            metrics["kl_divs"].append(kl_div.item())
            metrics["ppo_losses"].append(ppo_loss.item())
            metrics["critic_losses"].append(critic_loss.item())

        # Epoch average metrics.
        avg_raw_score = sum(metrics["raw_scores"]) / len(metrics["raw_scores"])
        avg_final_reward = sum(metrics["rewards"]) / len(metrics["rewards"])
        avg_kl_div = sum(metrics["kl_divs"]) / len(metrics["kl_divs"])
        avg_ppo_loss = sum(metrics["ppo_losses"]) / len(metrics["ppo_losses"])
        avg_critic_loss = sum(metrics["critic_losses"]) / len(metrics["critic_losses"])
        print(f"[Epoch {epoch+1}/{num_epochs}] ", end="")
        print(
            f"Reward: {avg_raw_score:.2f} | Reward (w/ KL): {avg_final_reward:.2f} | "
            + f"KL Div: {avg_kl_div:.4f} | PPO Loss: {avg_ppo_loss:.4f} | "
            + f"Critic Loss: {avg_critic_loss:.4f}"
        )

        # Sample response for qualitative progress assessment.
        actor_model.eval()  # eval mode (e.g., disable dropouts)
        sample_prompt = SAMPLE_PROMPT
        _, _, sample_response = generate(tokenizer, actor_model, sample_prompt, max_length)
        print(f"[SAMPLE] {sample_prompt}{sample_response.replace('\n', ' ')}\n")

    print("Training finished!")

# %% [markdown]
# ## Run Training!
#
# During training we should be monitoring the KL divergence, which should be positive but not too
# large. Also the losses should trend downwards, but they can be very noisy.

# %%
# Takes ~15 minutes on a modern CPU/GPU (RTX 4090).
rlhf_fine_tuning(actor_model, critic_model)
# Out:
# [transformers] `use_return_dict` is deprecated! Use `return_dict` instead!
# [Epoch 1/50] Reward: -1.20 | Reward (w/ KL): -1.19 | KL Div: -0.1327 | PPO Loss: -0.5361 | Critic Loss: 14.1066
# [SAMPLE] Once upon a time, there was a little girl named Lily. She loved to play outside in the park. One day, she saw a big, scary dog. The dog barked loudly and scared her. Lily ran away, but she forgot her favorite toy in the park.  When she
#
# [Epoch 2/50] Reward: -0.65 | Reward (w/ KL): -0.62 | KL Div: -0.3352 | PPO Loss: -0.7060 | Critic Loss: 11.4947
# [SAMPLE] Once upon a time there was a little girl named Annie. She was three years old and loved to explore the world around her.  One day Annie went for a walk and saw a beautiful landscape. She was so excited that she ran right into it.  When she got there she was
#
# [Epoch 3/50] Reward: -0.72 | Reward (w/ KL): -0.74 | KL Div: 0.1943 | PPO Loss: -0.3159 | Critic Loss: 18.3836
# [SAMPLE] Once upon a time there was a brave little girl. She was very brave and loved to explore the world. One day, the little girl wanted to go on an adventure. She asked her mom to permit her to go on the adventure. Her mom said yes, and the little girl was so happy
#
# [Epoch 4/50] Reward: 1.06 | Reward (w/ KL): 1.02 | KL Div: 0.4538 | PPO Loss: -2.6263 | Critic Loss: 25.6039
# [SAMPLE] Once upon a time there was a little girl. She was very brave and liked to explore. One day she decided to go on an adventure. She started to walk through a forest. As she walked, she heard a sound. It was a bird singing a happy song. The little girl followed the
#
# [Epoch 5/50] Reward: 1.89 | Reward (w/ KL): 1.68 | KL Div: 2.1138 | PPO Loss: -1.4479 | Critic Loss: 10.6453
# [SAMPLE] Once upon a time, there was a little girl named Lily. She loved to play outside and collect pretty pebbles. One day, she found a shiny pebble that she thought was very pretty.  But then, Lily started to worry that her pebble might get lost.
#
# [Epoch 6/50] Reward: 3.38 | Reward (w/ KL): 2.86 | KL Div: 5.1855 | PPO Loss: -0.3332 | Critic Loss: 15.9315
# [SAMPLE] Once upon a time, there was a little girl named Lily. One day, Lily's mommy asked her to help cook dinner. Lily was so excited to help her mommy, but she didn't know how to cook.   "Mommy, can you help me cook?" asked
#
# [Epoch 7/50] Reward: 4.63 | Reward (w/ KL): 3.93 | KL Div: 7.0182 | PPO Loss: -0.3529 | Critic Loss: 5.5950
# [SAMPLE] Once upon a time, there was a little boy named Timmy. Timmy loved to play with his toys and run around outside. One day, Timmy found a big rock and he wanted to take it home. But the rock was too heavy for him to carry, so he asked his dad
#
# [Epoch 8/50] Reward: 5.43 | Reward (w/ KL): 4.59 | KL Div: 8.4142 | PPO Loss: -0.1701 | Critic Loss: 4.6574
# [SAMPLE] Once upon a time, there was a boy named Timmy. Timmy loved to play outside with his friends. One day, Timmy saw a big van driving down the street. The van was carrying lots of toys and candy.  Timmy's friends came over and asked if they could
#
# [Epoch 9/50] Reward: 5.48 | Reward (w/ KL): 4.56 | KL Div: 9.1510 | PPO Loss: -0.1955 | Critic Loss: 5.8183
# [SAMPLE] Once upon a time, there was a little girl named Lily. She had a dog named Max. One day, Max got lost in the woods and Lily was very worried. She looked for Max for a long time but couldn't find him.   Suddenly, Max appeared from behind a tree
#
# [Epoch 10/50] Reward: 5.84 | Reward (w/ KL): 4.72 | KL Div: 11.1839 | PPO Loss: -0.0141 | Critic Loss: 11.6906
# [SAMPLE] Once upon a time, there was a bird named Jack. Jack was very hungry and wanted to eat some juicy berries. But when he looked out the window, he saw a big, scary cat waiting for him.  Jack was scared and didn't know what to do. He asked his friend
#
# [Epoch 11/50] Reward: 6.45 | Reward (w/ KL): 5.00 | KL Div: 14.4317 | PPO Loss: -0.1211 | Critic Loss: 5.1791
# [SAMPLE] Once upon a time, there was a little girl named Lily. Lily loved to explore and go on adventures. One day, she went to the forest and saw a small bird. The bird said, "Hello, Lily! What are you doing?" Lily replied, "I am looking for worms to
#
# [Epoch 12/50] Reward: 6.82 | Reward (w/ KL): 5.04 | KL Div: 17.7459 | PPO Loss: -0.0052 | Critic Loss: 4.8049
# [SAMPLE] Once upon a time, there was a bird named Benny. Benny was very intelligent and loved to fly high in the sky. One day, Benny met a little squirrel named Sammy.  "Hi, Sammy! Do you want to fly with me?" Benny asked.  Sammy was scared
#
# [Epoch 13/50] Reward: 7.58 | Reward (w/ KL): 5.72 | KL Div: 18.6106 | PPO Loss: 0.1068 | Critic Loss: 6.9483
# [SAMPLE] Once upon a time, there was a bird with a big, bossy wing. The bird loved to show off its big wing. The bird was not afraid of the bossy wing. It would fly high in the sky and show off its big wing to all the other animals.  One
#
# [Epoch 14/50] Reward: 9.42 | Reward (w/ KL): 7.39 | KL Div: 20.3518 | PPO Loss: -0.8170 | Critic Loss: 2.9456
# [SAMPLE] Once upon a time, there was a little girl named Mia. She loved to collect pretty rocks. One day, she found a big, round rock. It was the most beautiful rock she had ever seen. Mia knew that the rock had value. It was special and important to her.
#
# [Epoch 15/50] Reward: 7.55 | Reward (w/ KL): 5.56 | KL Div: 19.9037 | PPO Loss: -0.1000 | Critic Loss: 11.2986
# [SAMPLE] Once upon a time, there was a little girl named Sarah who was very curious. She had been watching the ostrich for a while when the ostrich noticed her. Sarah was very excited and she smiled at the ostrich.  The ostrich was so friendly that Sarah wanted to pet the
#
# [Epoch 16/50] Reward: 9.76 | Reward (w/ KL): 7.03 | KL Div: 27.3241 | PPO Loss: -0.1805 | Critic Loss: 6.0442
# [SAMPLE] Once upon a time, there was a little rabbit named Bun Bun. Bun Bun was very curious and loved to explore. One day, Bun Bun saw a big, juicy carrot and decided to take a bite. But the carrot was too far away for Bun Bun to reach.  Bun Bun
#
# [Epoch 17/50] Reward: 7.46 | Reward (w/ KL): 5.34 | KL Div: 21.2123 | PPO Loss: 0.0549 | Critic Loss: 10.1164
# [SAMPLE] Once upon a time there was a little bird called Chirpy. Chirpy was very small, with big wings.  One day Chirpy was flying around when she saw a tall tree with a lot of bright yellow fruit. Chirpy was so excited that she flew right up
#
# [Epoch 18/50] Reward: 8.67 | Reward (w/ KL): 6.68 | KL Div: 19.8925 | PPO Loss: -0.2835 | Critic Loss: 5.7712
# [SAMPLE] Once upon a time, there was a small bird. The bird saw the lion and the lion and the bird fighting. The bird and the lion were scared.  The bird and the lion saw the lion and the bird fighting. The bird and the lion stopped fighting. They asked the bird and
#
# [Epoch 19/50] Reward: 8.75 | Reward (w/ KL): 6.50 | KL Div: 22.4258 | PPO Loss: -0.3795 | Critic Loss: 8.4438
# [SAMPLE] Once upon a time there was a big, hairy bug. The bug was very small and the bug was always looking for something to do. One day the bug saw a big, yellow bird in a tree. The bug thought the bird was so beautiful and the bug wanted to be friends.
#
# [Epoch 20/50] Reward: 10.52 | Reward (w/ KL): 8.13 | KL Div: 23.9148 | PPO Loss: -0.1458 | Critic Loss: 6.0052
# [SAMPLE] Once upon a time there was a little bird. The bird was so small and helpless. The bird had never seen a bird like this before. It was so scared.  The bird wanted to help the little bird. The bird said to the bird, “What can I do to help
#
# [Epoch 21/50] Reward: 9.12 | Reward (w/ KL): 7.08 | KL Div: 20.4352 | PPO Loss: 0.5854 | Critic Loss: 7.2011
# [SAMPLE] Once upon a time, there was a wise old owl. The owl was very old and wise. The owl lived in a tree near a big, green bush.  One day, a little bird came to the owl. The bird saw the owl in the tree and said, "Hello,
#
# [Epoch 22/50] Reward: 11.76 | Reward (w/ KL): 9.27 | KL Div: 24.9053 | PPO Loss: -0.7724 | Critic Loss: 2.5286
# [SAMPLE] Once upon a time, there was a little girl named Mary. Mary was only three years old and she was very curious. One day, Mary saw a big, scary wolf in the forest. The wolf was big and black, and it looked very scary.  Mary was very brave, so
#
# [Epoch 23/50] Reward: 11.02 | Reward (w/ KL): 8.21 | KL Div: 28.0843 | PPO Loss: 0.4590 | Critic Loss: 4.6223
# [SAMPLE] Once upon a time there was a little boy named Timmy. He was a very curious 3 year old. Timmy loved to explore and discover new things.  One day, Timmy was outside playing when he noticed something shining in a nearby bush. He went closer and saw a silver key
#
# [Epoch 24/50] Reward: 12.04 | Reward (w/ KL): 9.06 | KL Div: 29.8028 | PPO Loss: -0.1331 | Critic Loss: 2.7986
# [SAMPLE] Once upon a time, there was a little bird called Tweety. Tweety was very small and the bird was very fragile. The bird was very quiet and the bird had a very soft, warm feather. The bird was very curious about the bird and wanted to be friends with it.
#
# [Epoch 25/50] Reward: 11.14 | Reward (w/ KL): 8.58 | KL Div: 25.6215 | PPO Loss: -0.0084 | Critic Loss: 4.8635
# [SAMPLE] Once upon a time, there was a little girl called Jane. Jane was very brave and liked to help people. One day, a bad man came to the town. The bad man wanted to take things away from the people who lived there.  Jane saw the bad man and wanted to help
#
# [Epoch 26/50] Reward: 10.40 | Reward (w/ KL): 8.37 | KL Div: 20.2498 | PPO Loss: -0.4074 | Critic Loss: 3.6006
# [SAMPLE] Once upon a time, there was a wise old owl who lived in a tree. The owl was very wise and always helped the animals in the forest when they were scared of the storm. One day, a little rabbit saw the owl and the rabbit and felt sorry for the owl. The rabbit decided
#
# [Epoch 27/50] Reward: 9.85 | Reward (w/ KL): 7.95 | KL Div: 18.9671 | PPO Loss: -0.3278 | Critic Loss: 3.0077
# [SAMPLE] Once upon a time, there was a small bird named Tiny. Tiny was very lonely and wanted to make friends. One day, Tiny saw a big cat named Whiskers near the tree. Tiny thought Whiskers would be a nice friend.  Tiny went to Whiskers and
#
# [Epoch 28/50] Reward: 9.28 | Reward (w/ KL): 7.60 | KL Div: 16.7461 | PPO Loss: -0.3763 | Critic Loss: 4.7247
# [SAMPLE] Once upon a time, there was a brave little bird named Bobo. Bobo loved to fly high in the sky and see all the pretty sights. One day, Bobo met a big bird named Chirpy.  Chirpy said to Bobo, "Let's be friends
#
# [Epoch 29/50] Reward: 10.40 | Reward (w/ KL): 8.24 | KL Div: 21.6075 | PPO Loss: 0.4556 | Critic Loss: 3.9755
# [SAMPLE] Once upon a time there was a little boy named Tommy. Tommy was 3 years old and he loved to help his mom and dad. One day Tommy and his parents were walking in the woods when they saw a big tree with a bird perched on a branch. The bird noticed Tommy and it began to
#
# [Epoch 30/50] Reward: 10.67 | Reward (w/ KL): 8.21 | KL Div: 24.5255 | PPO Loss: -0.5486 | Critic Loss: 3.2174
# [SAMPLE] Once upon a time, there was a little girl named Lily. Lily had a pink cat named Mittens. Mittens was a harmless cat who loved to play with Lily.  One day, Lily and Mittens were playing in the park. Mittens saw a bird and wanted to catch it
#
# [Epoch 31/50] Reward: 11.30 | Reward (w/ KL): 8.58 | KL Div: 27.2567 | PPO Loss: -0.3882 | Critic Loss: 2.7767
# [SAMPLE] Once upon a time, there was a little girl named Lily. Lily loved to bake cookies with her mom. One day, Lily's friend Timmy came over to play. Timmy saw Lily's cookies and asked if he could have one. Lily said no because she didn't want anyone else to
#
# [Epoch 32/50] Reward: 9.29 | Reward (w/ KL): 7.00 | KL Div: 22.9319 | PPO Loss: 0.3504 | Critic Loss: 8.6676
# [SAMPLE] Once upon a time, there was a little girl named Sophie. Sophie was very independent and she liked to do things by herself.   One day, Sophie was walking in the park and saw a little mouse. She thought it was very cute, so she decided to try and catch it.
#
# [Epoch 33/50] Reward: 11.68 | Reward (w/ KL): 9.33 | KL Div: 23.4201 | PPO Loss: -0.5453 | Critic Loss: 4.0538
# [SAMPLE] Once upon a time, there was a bird named Tweety. Tweety was a very colorful bird. One day, Tweety met a squirrel named Sammy. Sammy was eating a nut when Tweety flew over and asked Sammy, "Why are you eating that nut?" Sammy replied, "It's
#
# [Epoch 34/50] Reward: 9.97 | Reward (w/ KL): 7.72 | KL Div: 22.4372 | PPO Loss: -0.0365 | Critic Loss: 2.4978
# [SAMPLE] Once upon a time, there was a little girl called Sally. Sally was only three years old. One day, Sally was playing in the garden when she saw something very unusual. It was a big, tall tree with a huge branch in the middle. Sally was very curious and wanted to know what
#
# [Epoch 35/50] Reward: 11.06 | Reward (w/ KL): 8.55 | KL Div: 25.1529 | PPO Loss: 0.1568 | Critic Loss: 6.3070
# [SAMPLE] Once upon a time there was a small bird. The bird was looking for a place to build its nest. The bird saw a nice branch in the tree and was very happy. The bird flew over to the branch and the bird saw that the branch was very thin. The bird was careful to make
#
# [Epoch 36/50] Reward: 13.39 | Reward (w/ KL): 10.04 | KL Div: 33.5250 | PPO Loss: -0.4406 | Critic Loss: 2.1873
# [SAMPLE] Once upon a time, there was a girl named Jane. Jane was three years old and loved to play in the big, wide world outside the window.  One day, Jane was playing in the garden when she saw the big, wide tree. She wanted to climb it, but she was
#
# [Epoch 37/50] Reward: 12.98 | Reward (w/ KL): 9.68 | KL Div: 33.0330 | PPO Loss: -0.1832 | Critic Loss: 2.0492
# [SAMPLE] Once upon a time, there was a little girl named Lily. She loved to play outside with her friends. One day, they decided to have a race. The race was in a big, scary forest. The birds flew high in the sky, and the squirrels climbed down the trees.
#
# [Epoch 38/50] Reward: 12.52 | Reward (w/ KL): 9.43 | KL Div: 30.8457 | PPO Loss: 0.0725 | Critic Loss: 2.0902
# [SAMPLE] Once upon a time there was a fat cat. The cat was very happy and the bird was too. The cat was always very curious and always loved to explore.  One day the cat saw something shiny in the grass. It was a small, round rock. The cat was excited to see
#
# [Epoch 39/50] Reward: 13.32 | Reward (w/ KL): 9.86 | KL Div: 34.6392 | PPO Loss: -0.5671 | Critic Loss: 1.7439
# [SAMPLE] Once upon a time, there was a little girl named Lily. Lily loved to play with her toys in the garden. One day, she found a beautiful flower and wanted to pick it. But the flower was too high for her to reach.  Lily asked her dad to help her.
#
# [Epoch 40/50] Reward: 14.80 | Reward (w/ KL): 10.60 | KL Div: 41.9984 | PPO Loss: 0.3387 | Critic Loss: 2.0542
# [SAMPLE] Once upon a time, there was a little girl called Lucy. The sky was a beautiful blue and the trees were a bright and cheerful green. The rabbit was hopping around in the garden, the sun was shining and the flowers were blooming.  The rabbit saw the rabbit and hopped over to
#
# [Epoch 41/50] Reward: 14.09 | Reward (w/ KL): 10.32 | KL Div: 37.6817 | PPO Loss: 0.0661 | Critic Loss: 3.4729
# [SAMPLE] Once upon a time there was a bunny. The bunny was very alert and watched the birds and squirrels. One day the bunny was hopping around the bush, watching the squirrels and the birds and squirrels. The bunny saw the bunny and the squirrels, and was curious. The bunny hopped
#
# [Epoch 42/50] Reward: 12.94 | Reward (w/ KL): 9.43 | KL Div: 35.0853 | PPO Loss: -0.4383 | Critic Loss: 5.2781
# [SAMPLE] Once upon a time, there was a little boy who loved to watch the fish swimming in the pond. Every day he would go to the pond and watch the fish swimming and darting about. One day, the fish noticed a big, round, green frog in the pond. The fish watched the
#
# [Epoch 43/50] Reward: 14.09 | Reward (w/ KL): 10.31 | KL Div: 37.7773 | PPO Loss: -0.1464 | Critic Loss: 3.9029
# [SAMPLE] Once upon a time, there was a little bird called Fluffy. Fluffy was a very brave bird and loved to fly around the tree. The tree was big and had a long, thick branch.   One day, a squirrel came to the tree and saw the branch. The squirrel
#
# [Epoch 44/50] Reward: 13.31 | Reward (w/ KL): 9.65 | KL Div: 36.5661 | PPO Loss: -0.0090 | Critic Loss: 1.6986
# [SAMPLE] Once upon a time, there was a little bird named Buzzy. Buzzy lived in a big tree with many other bugs. Buzzy liked to watch the bugs play and the bugs move around. One day, the sun was shining and the bugs were flying high in the sky.  As
#
# [Epoch 45/50] Reward: 13.89 | Reward (w/ KL): 9.99 | KL Div: 39.0028 | PPO Loss: -0.6322 | Critic Loss: 3.3617
# [SAMPLE] Once upon a time, there was a little girl named Lily. Lily loved to play hide and seek with her friends. One day, Lily found a hidden spot behind a big tree. She was so excited to hide there.   As she was hiding, she saw a bird flying in the
#
# [Epoch 46/50] Reward: 12.49 | Reward (w/ KL): 9.48 | KL Div: 30.0315 | PPO Loss: -0.4336 | Critic Loss: 1.8017
# [SAMPLE] Once upon a time, there was a little mouse called Fred. He was very clever and was always looking for something to eat. One day, he found a big piece of cheese and he was so excited. He ate it all up.   But then he noticed something else. A big
#
# [Epoch 47/50] Reward: 12.12 | Reward (w/ KL): 9.66 | KL Div: 24.6745 | PPO Loss: -0.5825 | Critic Loss: 2.9117
# [SAMPLE] Once upon a time, there was a little girl who loved to go outside and listen to the birds sing. She would sit in the grass and watch the bumblebees buzzing around the flowers.  One day, the girl saw something special in the sky. A big, white bird with
#
# [Epoch 48/50] Reward: 12.21 | Reward (w/ KL): 8.90 | KL Div: 33.1096 | PPO Loss: 0.4474 | Critic Loss: 2.8341
# [SAMPLE] Once upon a time, there was a little bird named Benny. Benny liked to sing all day long in the tree. The tree was big and green, and the leaves were pretty. Benny liked to watch the squirrels climb the tree and the squirrels scatter nuts around the branch.
#
# [Epoch 49/50] Reward: 13.82 | Reward (w/ KL): 9.60 | KL Div: 42.1697 | PPO Loss: -0.0411 | Critic Loss: 2.4788
# [SAMPLE] Once upon a time, there was a big, bossy bear. The bear lived in the forest and was always bossing the animals around. One day, a small rabbit came hopping by and asked the bear for help. The bear didn't want the rabbit to disturb the rabbit, so he didn
#
# [Epoch 50/50] Reward: 14.37 | Reward (w/ KL): 10.50 | KL Div: 38.7366 | PPO Loss: -0.5490 | Critic Loss: 2.8450
# [SAMPLE] Once upon a time, there was a little girl called Daisy. Daisy was very curious and liked to explore.  One day, Daisy saw a very big bird and was curious to see what it was. She watched the bird carefully and observed it carefully. The bird was so big and graceful.
#
# Training finished!

# %% [markdown]
# Let's now see how our model generates stories: hopefully, we will get a strong preference towards
# animals' stories!

# %%
_, _, sample_response = generate(tokenizer, actor_model, SAMPLE_PROMPT)
print(f"[SAMPLE] {SAMPLE_PROMPT}{sample_response.replace('\n', ' ')}")
# Out:
# [SAMPLE] Once upon a time, there was a little girl named Lily. Lily liked to peek at the bees and watch them fly around. One day, Lily saw a bee that was hurt. The bee had a bump on its wing and the bee was sad. Lily wanted to help the bee feel better.

# %% [markdown]
# ## Pseudo-statistic
#
# Finally, let's compute an approximate statistic about how often the fine-tuned model uses words
# related to animals compared to the reference model. We should see some bias :)

# %%
ref_model_count, ref_model_total, fine_tuned_count, fine_tuned_total = 0, 0, 0, 0

for i in range(100):
    print(f"\rSample: {i} ...", end="")
    _, _, ref_model_text = generate(tokenizer, ref_model, SAMPLE_PROMPT)
    _, _, fine_tuned_text = generate(tokenizer, actor_model, SAMPLE_PROMPT)
    ref_model_text_words = ref_model_text.split()
    fine_tuned_text_words = fine_tuned_text.split()
    ref_model_total += len(ref_model_text_words)
    fine_tuned_total += len(fine_tuned_text_words)
    for word in RLHF.ANIMAL_WORDS:
        ref_model_count += ref_model_text_words.count(word)
        fine_tuned_count += fine_tuned_text_words.count(word)

print(f"\rFined tuned: {(fine_tuned_count / fine_tuned_total) * 100:.1f}%")
print(f"Reference model: {(ref_model_count / ref_model_total) * 100:.1f}%")
# Out:
# Fined tuned: 8.9%
# Reference model: 0.8%

# %% [markdown]
# ## DPO (Direct Preference Optimization)
#
# [DPO](https://arxiv.org/abs/2305.18290) is a more recent technique that eliminates the need for a
# separate Reward Model and the PPO loop entirely. Instead, DPO directly optimizes the policy network
# to satisfy human preferences.
#
# ### How DPO works
#
# While PPO optimizes a reward function $R(x, y)$, DPO proves mathematically that the optimal reward
# function can be expressed in terms of the optimal policy. This allows us to substitute the reward
# model with the policy model itself in the loss function.
#
# The loss function minimizes the likelihood of "rejected" responses ($y_l$) while maximizing "chosen"
# responses ($y_w$):
#
# $$
# \mathcal{L}_{DPO}(\pi_{\theta}; \pi_{\text{ref}}) = -E_{(x, y_w, y_l) \sim \mathcal{D}} \left[ \log \sigma \left( \beta \log \frac{\pi_{\theta}(y_w | x)}{\pi_{\text{ref}}(y_w | x)} - \beta \log \frac{\pi_{\theta}(y_l | x)}{\pi_{\text{ref}}(y_l | x)} \right) \right]
# $$
#
# Where:
#
# - $\pi_{\theta}$ is our model being trained.
# - $\pi_{\text{ref}}$ is the frozen reference model.
# - $\beta$ is a hyperparameter (similar to KL coefficient) controlling deviation from the reference.
#
# ### Creating a Preference Dataset
#
# DPO is typically an **Offline** algorithm—it requires a dataset of `(prompt, chosen, rejected)`
# tuples beforehand. To demonstrate it in this notebook, we will synthesize a preference dataset on
# the fly using our existing models and the `animals_stories_reward` function!

# %%
def create_preference_batch(tokenizer, model, prompts, batch_size=1):
    """Synthesizes a batch of preference data by generating two responses and ranking them."""
    batch_data = []

    for _ in range(batch_size):
        prompt = random.choice(prompts)

        # Generate two different outputs for the same prompt
        _, id1, text1 = generate(tokenizer, model, prompt)
        _, id2, text2 = generate(tokenizer, model, prompt)

        # Score them using our 'fake' reward function
        r1 = animals_stories_reward(text1).item()
        r2 = animals_stories_reward(text2).item()

        # Determine chosen (winner) and rejected (loser)
        # We need the prompt_ids, chosen_ids, and rejected_ids
        prompt_tokens = tokenizer(prompt, return_tensors="pt").input_ids.to(DEVICE)

        if r1 > r2:
            batch_data.append(
                {
                    "prompt_ids": prompt_tokens,
                    "chosen_ids": id1,
                    "rejected_ids": id2,
                    "diff": r1 - r2,
                }
            )
        else:
            batch_data.append(
                {
                    "prompt_ids": prompt_tokens,
                    "chosen_ids": id2,
                    "rejected_ids": id1,
                    "diff": r2 - r1,
                }
            )

    return batch_data

# %% [markdown]
# Now we can implement the DPO fine-tuning loop. Notice how much simpler this is than PPO: no critics,
# no advantage calculation, just a straightforward gradient update based on the loss formula.

# %%
def dpo_fine_tuning(
    actor_model: PreTrainedModel,
    ref_model: PreTrainedModel,
    num_epochs=10,
    beta=0.1,
    lr=1e-5,
    seed=42,
):
    """Fine-tune an LLM using Direct Preference Optimization (DPO)."""
    init_random(seed=seed)
    optimizer = optim.Adam(actor_model.parameters(), lr=lr)

    # We don't need a critic model for DPO!
    actor_model.train()

    for epoch in range(num_epochs):
        epoch_loss = 0

        # In a real scenario, we would iterate over a fixed dataset.
        # Here, we generate preference pairs on the fly to simulate the dataset.
        # We process 20 batches of synthetic data per epoch.
        for _ in range(20):
            # 1. Create a synthetic preference pair (Winner vs Loser)
            # In practice, this step happens *offline* before training starts.
            batch_data = create_preference_batch(tokenizer, actor_model, RLHF.PROMPTS)
            item = batch_data[0]  # Batch size 1 for simplicity

            # Prepare inputs
            # For DPO, we need log probs of the Chosen sequence and Rejected sequence
            # from BOTH the policy model (actor) and the reference model.
            prompt_len = item["prompt_ids"].shape[1]
            chosen_full = torch.cat([item["prompt_ids"], item["chosen_ids"]], dim=1)
            rejected_full = torch.cat([item["prompt_ids"], item["rejected_ids"]], dim=1)

            # Helper to get log probabilities for a specific sequence
            def get_log_probs(model, full_seq, response_seq):
                mask = torch.ones_like(full_seq)
                logits = model(full_seq, attention_mask=mask).logits
                # Use our existing helper to extract log_probs for the response part only
                return actual_log_probs(logits, response_seq, prompt_len).sum(dim=1)

            # 2. Compute Log Probs
            # Policy Log Probs
            policy_chosen_logps = get_log_probs(actor_model, chosen_full, item["chosen_ids"])
            policy_rejected_logps = get_log_probs(actor_model, rejected_full, item["rejected_ids"])

            # Reference Log Probs (No Grad)
            with torch.no_grad():
                ref_chosen_logps = get_log_probs(ref_model, chosen_full, item["chosen_ids"])
                ref_rejected_logps = get_log_probs(ref_model, rejected_full, item["rejected_ids"])

            # 3. Calculate DPO Loss
            # pi_logratios = log(pi(yw)/pi(yl)) = log(pi(yw)) - log(pi(yl))
            policy_log_ratios = policy_chosen_logps - policy_rejected_logps
            ref_log_ratios = ref_chosen_logps - ref_rejected_logps

            # The core DPO logic: logits = beta * (policy_diff - ref_diff)
            logits = beta * (policy_log_ratios - ref_log_ratios)

            # The loss is -log(sigmoid(logits))
            losses = -F.logsigmoid(logits)
            loss = losses.mean()

            # 4. Update
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        print(f"[Epoch {epoch+1}/{num_epochs}] DPO Loss: {epoch_loss/20:.4f}")

        # Qualitative check
        if (epoch + 1) % 5 == 0:
            actor_model.eval()
            _, _, sample = generate(tokenizer, actor_model, SAMPLE_PROMPT)
            print(f"[SAMPLE] {SAMPLE_PROMPT}{sample}\n")
            actor_model.train()

# %%
tokenizer = make_tokenizer()
ref_model, actor_model, critic_model = make_training_models(tokenizer)
dpo_fine_tuning(actor_model, ref_model)
# Out:
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# [transformers] GPTNeoForCausalLM LOAD REPORT from: roneneldan/TinyStories-33M
# Key                                                   | Status     |  |
# ------------------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3}.attn.attention.bias        | UNEXPECTED |  |
# transformer.h.{0, 1, 2, 3}.attn.attention.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# [transformers] GPTNeoForSequenceClassification LOAD REPORT from: roneneldan/TinyStories-33M
# Key                                                   | Status     |
# ------------------------------------------------------+------------+-
# transformer.h.{0, 1, 2, 3}.attn.attention.bias        | UNEXPECTED |
# transformer.h.{0, 1, 2, 3}.attn.attention.masked_bias | UNEXPECTED |
# score.weight                                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# [Epoch 1/10] DPO Loss: 0.6935
# [Epoch 2/10] DPO Loss: 0.6934
# [Epoch 3/10] DPO Loss: 0.6912
# [Epoch 4/10] DPO Loss: 0.6912
# [Epoch 5/10] DPO Loss: 0.6938
# [SAMPLE] Once upon a time, there was a little boy named Tim. Tim was very hungry. He wanted to find something to eat.
#
# Tim went to his mom and said, "Mom, I want to eat. Can you help me find food?" His mom said, "Yes, Tim.
#
# [Epoch 6/10] DPO Loss: 0.6903
# [Epoch 7/10] DPO Loss: 0.6911
# [Epoch 8/10] DPO Loss: 0.6884
# [Epoch 9/10] DPO Loss: 0.6868
# [Epoch 10/10] DPO Loss: 0.6901
# [SAMPLE] Once upon a time, there was a little girl named Lily. She loved to play outside in the sun. One day, she was playing with her friend, a little boy named Max.
#
# Max said, "Lily, do you want to go to the park?"
#
# Lily

# %% [markdown]
# ## GRPO (Group Relative Policy Optimization)
#
# [GRPO](https://arxiv.org/abs/2402.03300) is another efficiency improvement over PPO, famously used
# by DeepSeek. It simplifies the RLHF process by **removing the critic (value) model entirely**.
#
# ### How GRPO works
#
# PPO calculates "Advantage" by comparing the reward against a Critic's prediction ($A = R - V(s)$).
# GRPO calculates "Advantage" by comparing a response's reward against the average reward of a
# **group** of other responses to the same prompt.
#
# 1. Sample a group of outputs $\{y_1, y_2, ..., y_G\}$ for the same prompt $x$.
# 2. Score them all: $\{r_1, r_2, ..., r_G\}$.
# 3. Compute the advantage for each output by normalizing within the group: $$ A_i = \frac{r_i -
#    \text{mean}(r)}{\text{std}(r) + \epsilon} $$
# 4. Update the policy using the PPO objective, but using this relative advantage instead of a critic.
#
# This significantly saves memory (no critic model needed!) and training stability.

# %%
def grpo_fine_tuning(
    actor_model: PreTrainedModel,
    ref_model: PreTrainedModel,
    num_epochs=10,
    group_size=4,  # Number of outputs to generate per prompt
    beta=0.1,  # KL penalty coefficient
    lr=1e-5,
    seed=42,
):
    """Fine-tune an LLM using Group Relative Policy Optimization (GRPO)."""
    init_random(seed=seed)
    optimizer = optim.Adam(actor_model.parameters(), lr=lr)
    actor_model.train()

    for epoch in range(num_epochs):
        epoch_rewards = []

        # Shuffle prompts
        epoch_prompts = RLHF.PROMPTS.copy()
        random.shuffle(epoch_prompts)

        # We assume small batch size of 1 prompt, but 'group_size' generations per prompt
        for prompt in epoch_prompts:

            # 1. Generate Group of Outputs
            # We generate 'group_size' completions for the single prompt
            group_outputs = []
            for _ in range(group_size):
                # Generate
                tokenized_prompt, response_ids, response_text = generate(
                    tokenizer, actor_model, prompt
                )
                group_outputs.append((response_ids, response_text))

            # 2. Score Outputs & Compute Group Stats
            rewards = []
            for _, text in group_outputs:
                r = animals_stories_reward(text).item()
                rewards.append(r)

            rewards_tensor = torch.tensor(rewards, device=DEVICE, dtype=torch.float32)
            mean_r = rewards_tensor.mean()
            std_r = rewards_tensor.std() + 1e-8

            # Compute Advantages: (r - mean) / std
            advantages = (rewards_tensor - mean_r) / std_r

            # 3. Update Loop (Process each member of the group)
            optimizer.zero_grad()

            for i, (response_ids, _) in enumerate(group_outputs):
                prompt_len = tokenized_prompt.input_ids.shape[1]
                response_len = response_ids.shape[1]

                # Reconstruct full sequence inputs
                full_ids = torch.cat([tokenized_prompt.input_ids, response_ids], dim=1)
                full_attention_mask = torch.cat(
                    [
                        tokenized_prompt.attention_mask,
                        torch.ones(1, response_len, device=DEVICE, dtype=torch.long),
                    ],
                    dim=1,
                )

                # Get log probs from Actor (Policy)
                actor_logits = actor_model(full_ids, attention_mask=full_attention_mask).logits
                actor_log_probs = actual_log_probs(actor_logits, response_ids, prompt_len)
                log_probs_sum = actor_log_probs.sum(dim=1).squeeze()

                # Get log probs from Reference (for KL calculation)
                with torch.no_grad():
                    ref_logits = ref_model(full_ids, attention_mask=full_attention_mask).logits
                    ref_log_probs = actual_log_probs(ref_logits, response_ids, prompt_len)
                    ref_log_probs_sum = ref_log_probs.sum(dim=1).squeeze()

                # Calculate KL for this specific sequence
                # (We approximate KL as the diff in log probs for the generated tokens)
                kl_penalty = beta * (log_probs_sum - ref_log_probs_sum)

                # GRPO Loss Objective
                # In standard PPO: Loss = -min(ratio * A, clip * A).
                # In simple GRPO/AWR (Advantage Weighted Regression), we can weight the
                # policy gradient by the advantage.
                # Here we use a simplified objective: maximize (Advantage * LogProb) - KL penalty
                # We negate it because we are minimizing loss.

                # Note: Full GRPO usually includes the clipping mechanism of PPO too.
                # For simplicity in this notebook, we show the core idea: Advantage-weighted
                # gradient.

                # A_i is a scalar constant for this step
                adv = advantages[i].item()

                loss = -(adv * log_probs_sum - kl_penalty)

                # Backpropagate (accumulate gradients over the group)
                # We divide by group_size to average the gradients
                (loss / group_size).backward()

            optimizer.step()
            epoch_rewards.append(mean_r.item())

        avg_reward = sum(epoch_rewards) / len(epoch_rewards)
        print(f"[Epoch {epoch+1}/{num_epochs}] Avg Group Reward: {avg_reward:.4f}")

        if (epoch + 1) % 5 == 0:
            actor_model.eval()
            _, _, sample = generate(tokenizer, actor_model, SAMPLE_PROMPT)
            print(f"[SAMPLE] {SAMPLE_PROMPT}{sample}\n")
            actor_model.train()

# %%
tokenizer = make_tokenizer()
ref_model, actor_model, critic_model = make_training_models(tokenizer)
grpo_fine_tuning(actor_model, ref_model)
# Out:
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# [transformers] GPTNeoForCausalLM LOAD REPORT from: roneneldan/TinyStories-33M
# Key                                                   | Status     |  |
# ------------------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3}.attn.attention.bias        | UNEXPECTED |  |
# transformer.h.{0, 1, 2, 3}.attn.attention.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# [transformers] GPTNeoForSequenceClassification LOAD REPORT from: roneneldan/TinyStories-33M
# Key                                                   | Status     |
# ------------------------------------------------------+------------+-
# transformer.h.{0, 1, 2, 3}.attn.attention.bias        | UNEXPECTED |
# transformer.h.{0, 1, 2, 3}.attn.attention.masked_bias | UNEXPECTED |
# score.weight                                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# [Epoch 1/10] Avg Group Reward: -0.8354
# [Epoch 2/10] Avg Group Reward: -0.8188
# [Epoch 3/10] Avg Group Reward: -0.7198
# [Epoch 4/10] Avg Group Reward: -0.4115
# [Epoch 5/10] Avg Group Reward: -0.2260
# [SAMPLE] Once upon a time, there was a boy named Timmy. Timmy loved to play outside and explore. One day, he went to the park and saw a big tree. He wanted to climb it, but he didn't have an axe.
#
# A man walked by and saw Tim
#
# [Epoch 6/10] Avg Group Reward: -0.3615
# [Epoch 7/10] Avg Group Reward: 0.0177
# [Epoch 8/10] Avg Group Reward: -0.2969
# [Epoch 9/10] Avg Group Reward: 0.1865
# [Epoch 10/10] Avg Group Reward: 0.5531
# [SAMPLE] Once upon a time, there was a little girl named Lily. She loved to play with her toys and her friends. One day, Lily's mom gave her a new toy. It was a big, red ball that bounced high.
#
# Lily was so excited to play with her new toy
